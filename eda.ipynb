# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
exc = pd.read_csv(r"C:\Users\user1\Documents\python\Python for Data Science\python libraries\Pandas\Pandas Exercises\pandas_project\excellent.csv")

# %%
exc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item_ID              4990 non-null   object
#  1   Store_ID             4990 non-null   object
#  2   Item_Store_ID        4990 non-null   object
#  3   Item_Weight          4188 non-null   float64
#  4   Item_Sugar_Content   4990 non-null   object
#  5   Item_Visibility      4990 non-null   float64
#  6   Item_Type            4990 non-null   object
#  7   Item_Price           4990 non-null   float64
#  8   Store_Start_Year     4990 non-null   int64
#  9   Store_Size           3540 non-null   object
#  10  Store_Location_Type  4990 non-null   object
#  11  Store_Type           4990 non-null   object
#  12  Item_Store_Returns   4990 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 506.9+ KB

# %%
# exc["Store_Size"].fillna()

# %%
exc.head(10)
# Out:
#   Item_ID      Store_ID       Item_Store_ID  Item_Weight Item_Sugar_Content  \
# 0   DRA12  BABATUNJI010  DRA12_BABATUNJI010        11.60          Low Sugar
# 1   DRA12  BABATUNJI013  DRA12_BABATUNJI013        11.60          Low Sugar
# 2   DRA12  BABATUNJI017  DRA12_BABATUNJI017        11.60          Low Sugar
# 3   DRA12  BABATUNJI018  DRA12_BABATUNJI018        11.60          Low Sugar
# 4   DRA12  BABATUNJI035  DRA12_BABATUNJI035        11.60    Ultra Low Sugar
# 5   DRA12  BABATUNJI045  DRA12_BABATUNJI045        11.60          Low Sugar
# 6   DRA24  BABATUNJI010  DRA24_BABATUNJI010        19.35       Normal Sugar
# 7   DRA24  BABATUNJI013  DRA24_BABATUNJI013        19.35       Normal Sugar
# 8   DRA24  BABATUNJI017  DRA24_BABATUNJI017        19.35       Normal Sugar
# 9   DRA24  BABATUNJI019  DRA24_BABATUNJI019          NaN       Normal Sugar
#
#    Item_Visibility    Item_Type  Item_Price  Store_Start_Year Store_Size  \
# ...

# %% [markdown]
# # What products cost more and at what location

# %%
exc.groupby("Item_ID").mean()
# Out:
#          Item_Weight  Item_Visibility  Item_Price  Store_Start_Year  \
# Item_ID
# DRA12         11.600         0.031956  354.665000       2008.166667
# DRA24         19.350         0.048062  410.220000       2002.000000
# DRA59          8.270         0.122633  463.105000       2004.000000
# DRB01          7.390         0.082104  472.255000       1999.000000
# DRB13          6.115         0.007061  475.130000       2010.333333
# ...              ...              ...         ...               ...
# NCZ30          6.590         0.024054  300.645000       2004.750000
# NCZ41         19.850         0.048391  314.305000       2008.750000
# NCZ42         10.500         0.011319  590.435000       2012.500000
# NCZ53          9.600         0.024484  471.883333       2004.666667
# NCZ54         14.650         0.080426  405.640000       2003.428571
#
#          Item_Store_Returns
# Item_ID
# DRA12           4609.000000
# DRA24           5615.547143
# DRA59           8406.278333
# ...

# %%
exc["Item_Type"].unique()
# exc["Item_Type"].nunique()
# Out:
# array(['Soft Drinks', 'Dairy', 'Hard Drinks', 'Canned', 'Frozen Foods',
#        'Fruits and Vegetables', 'Snack Foods', 'Baking Goods',
#        'Starchy Foods', 'Meat', 'Seafood', 'Breakfast', 'Breads',
#        'Health and Hygiene', 'Household', 'Others'], dtype=object)

# %%
exc[exc["Item_Price"] == exc["Item_Price"].max()]
# Out:
#      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 2752   FDS13  BABATUNJI017  FDS13_BABATUNJI017        6.465
#
#      Item_Sugar_Content  Item_Visibility Item_Type  Item_Price  \
# 2752          Low Sugar          0.12521    Canned      667.22
#
#       Store_Start_Year Store_Size Store_Location_Type         Store_Type  \
# 2752              2014        NaN           Cluster 2  Supermarket Type1
#
#       Item_Store_Returns
# 2752             2649.88

# %%
exc.sort_values("Item_Price", ascending=False).head(10)
# Out:
#      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 2752   FDS13  BABATUNJI017  FDS13_BABATUNJI017        6.465
# 4423   NCM05  BABATUNJI019  NCM05_BABATUNJI019          NaN
# 2606   FDR25  BABATUNJI017  FDR25_BABATUNJI017       17.000
# 4725   NCS29  BABATUNJI017  NCS29_BABATUNJI017        9.000
# 3691   FDY02  BABATUNJI017  FDY02_BABATUNJI017        8.945
# 1800   FDK51  BABATUNJI017  FDK51_BABATUNJI017       19.850
# 2858   FDS56  BABATUNJI017  FDS56_BABATUNJI017        5.785
# 4726   NCS29  BABATUNJI019  NCS29_BABATUNJI019          NaN
# 3692   FDY02  BABATUNJI019  FDY02_BABATUNJI019          NaN
# 3063   FDU12  BABATUNJI019  FDU12_BABATUNJI019          NaN
#
#      Item_Sugar_Content  Item_Visibility              Item_Type  Item_Price  \
# 2752          Low Sugar         0.125210                 Canned      667.22
# 4423          Low Sugar         0.104784     Health and Hygiene      665.06
# ...

# %%
exc.groupby("Store_Type")[["Item_Store_Returns"]].sum()
# Out:
#                    Item_Store_Returns
# Store_Type
# Grocery Store               598482.92
# Supermarket Type1         21284502.22
# Supermarket Type2          2770310.84
# Supermarket Type3          5803269.64

# %%
exc.groupby(["Store_Type", "Store_Location_Type"])[["Item_Store_Returns"]].sum()
# Out:
#                                        Item_Store_Returns
# Store_Type        Store_Location_Type
# Grocery Store     Cluster 1                     357844.32
#                   Cluster 3                     240638.60
# Supermarket Type1 Cluster 1                    6880331.05
#                   Cluster 2                   11996341.95
#                   Cluster 3                    2407829.22
# Supermarket Type2 Cluster 3                    2770310.84
# Supermarket Type3 Cluster 3                    5803269.64

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Store_Type', y='Item_Store_Returns', hue='Store_Location_Type', data=exc)
# Out:
# <AxesSubplot:xlabel='Store_Type', ylabel='Item_Store_Returns'>

# %%
exc.groupby(["Store_Location_Type"])[["Item_Store_Returns"]].sum()
# Out:
#                      Item_Store_Returns
# Store_Location_Type
# Cluster 1                    7238175.37
# Cluster 2                   11996341.95
# Cluster 3                   11222048.30

# %%
cat1 = exc.groupby(["Store_Type", "Store_Location_Type", "Item_ID",])[["Item_Store_Returns"]].sum()
# ,
cat1
# Out:
#                                                Item_Store_Returns
# Store_Type        Store_Location_Type Item_ID
# Grocery Store     Cluster 1           DRA24               1228.40
#                                       DRA59               1388.19
#                                       DRD15               1742.73
#                                       DRD25               1131.86
#                                       DRD60                454.41
# ...                                                           ...
# Supermarket Type3 Cluster 3           NCY18               5253.16
#                                       NCY54              12502.06
#                                       NCZ06               8244.27
#                                       NCZ53              14131.61
#                                       NCZ54              13808.69
#
# [3971 rows x 1 columns]

# %%
cl2 = exc[exc["Store_Location_Type"] == "Cluster 2"]
cl2
# Out:
#      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 2      DRA12  BABATUNJI017  DRA12_BABATUNJI017        11.60
# 4      DRA12  BABATUNJI035  DRA12_BABATUNJI035        11.60
# 5      DRA12  BABATUNJI045  DRA12_BABATUNJI045        11.60
# 8      DRA24  BABATUNJI017  DRA24_BABATUNJI017        19.35
# 11     DRA24  BABATUNJI035  DRA24_BABATUNJI035        19.35
# ...      ...           ...                 ...          ...
# 4975   NCZ41  BABATUNJI017  NCZ41_BABATUNJI017        19.85
# 4977   NCZ41  BABATUNJI035  NCZ41_BABATUNJI035        19.85
# 4978   NCZ42  BABATUNJI017  NCZ42_BABATUNJI017        10.50
# 4979   NCZ42  BABATUNJI035  NCZ42_BABATUNJI035        10.50
# 4987   NCZ54  BABATUNJI045  NCZ54_BABATUNJI045        14.65
#
#      Item_Sugar_Content  Item_Visibility           Item_Type  Item_Price  \
# 2             Low Sugar         0.041178         Soft Drinks      350.79
# 4       Ultra Low Sugar         0.000000         Soft Drinks      354.79
# ...

# %%
sp1[sp1[]]

# %%
sns.barplot(x="Store_Location_Type", y="Item_Store_Returns", data=exc)
# Out:
# <AxesSubplot:xlabel='Store_Location_Type', ylabel='Item_Store_Returns'>

# %%
sp1 = exc[exc["Store_Type"] == "Supermarket Type3"]
sp1
# Out:
#      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 10     DRA24  BABATUNJI027  DRA24_BABATUNJI027          NaN
# 16     DRA59  BABATUNJI027  DRA59_BABATUNJI027          NaN
# 19     DRB01  BABATUNJI027  DRB01_BABATUNJI027          NaN
# 48     DRC36  BABATUNJI027  DRC36_BABATUNJI027          NaN
# 51     DRC49  BABATUNJI027  DRC49_BABATUNJI027          NaN
# ...      ...           ...                 ...          ...
# 4937   NCY18  BABATUNJI027  NCY18_BABATUNJI027          NaN
# 4954   NCY54  BABATUNJI027  NCY54_BABATUNJI027          NaN
# 4961   NCZ06  BABATUNJI027  NCZ06_BABATUNJI027          NaN
# 4981   NCZ53  BABATUNJI027  NCZ53_BABATUNJI027          NaN
# 4986   NCZ54  BABATUNJI027  NCZ54_BABATUNJI027          NaN
#
#      Item_Sugar_Content  Item_Visibility           Item_Type  Item_Price  \
# 10         Normal Sugar         0.039735         Soft Drinks      414.47
# 16         Normal Sugar         0.127308         Soft Drinks      466.73
# ...

# %%
cl2.sort_values("Item_Store_Returns", ascending=False).head(10)
# Out:
#      Item_ID      Store_ID       Item_Store_ID  Item_Weight  \
# 1711   FDK03  BABATUNJI017  FDK03_BABATUNJI017       12.600
# 1758   FDK28  BABATUNJI017  FDK28_BABATUNJI017        5.695
# 3835   FDY55  BABATUNJI045  FDY55_BABATUNJI045       16.750
# 2925   FDT16  BABATUNJI045  FDT16_BABATUNJI045        9.895
# 948    FDD44  BABATUNJI017  FDD44_BABATUNJI017        8.050
# 2662   FDR45  BABATUNJI045  FDR45_BABATUNJI045       10.800
# 317    DRJ39  BABATUNJI045  DRJ39_BABATUNJI045       20.250
# 2633   FDR34  BABATUNJI017  FDR34_BABATUNJI017       17.000
# 683    FDB37  BABATUNJI035  FDB37_BABATUNJI035       20.250
# 3532   FDX09  BABATUNJI035  FDX09_BABATUNJI035        9.000
#
#      Item_Sugar_Content  Item_Visibility              Item_Type  Item_Price  \
# 1711       Normal Sugar         0.074339                  Dairy      638.84
# 1758          Low Sugar         0.065961           Frozen Foods      648.16
# ...

# %%
cl2items = cl2.groupby(["Item_ID", "Item_Type"])[["Item_Store_Returns"]].sum()
#cl2items
cl2items.reset_index(inplace=True)
cl2items
# Out:
#     Item_ID           Item_Type  Item_Store_Returns
# 0     DRA12         Soft Drinks            18436.00
# 1     DRA24         Soft Drinks            11465.08
# 2     DRA59         Soft Drinks             6015.50
# 3     DRB13         Soft Drinks             9962.04
# 4     DRB24         Soft Drinks            20466.70
# ..      ...                 ...                 ...
# 869   NCZ18           Household            36147.95
# 870   NCZ30           Household             2410.20
# 871   NCZ41  Health and Hygiene            10639.48
# 872   NCZ42           Household            20739.67
# 873   NCZ54           Household             5685.93
#
# [874 rows x 3 columns]

# %%
cl2items[cl2items["Item_Store_Returns"] == cl2items["Item_Store_Returns"].max()]
# Out:
#    Item_ID Item_Type  Item_Store_Returns
# 85   FDA15     Dairy             46066.7

# %%
cl2itemrank = cl2items.sort_values("Item_Store_Returns", ascending=False).head(10)
cl2itemrank
# Out:
#     Item_ID              Item_Type  Item_Store_Returns
# 85    FDA15                  Dairy            46066.70
# 525   FDT21            Snack Foods            44821.65
# 238   FDG45  Fruits and Vegetables            44070.97
# 110   FDB11          Starchy Foods            39382.07
# 52    DRJ51                  Dairy            37434.61
# 384   FDN51                   Meat            37191.58
# 684   FDZ20  Fruits and Vegetables            36878.67
# 234   FDG26                 Canned            36527.45
# 869   NCZ18              Household            36147.95
# 307   FDK03                  Dairy            35606.98

# %%
plt.figure(figsize=(20,7))
sns.barplot(y="Item_Store_Returns",
            x="Item_ID",
            data=cl2itemrank,
            order=cl2itemrank.sort_values("Item_Store_Returns", ascending=False)['Item_ID'])
# Out:
# <AxesSubplot:xlabel='Item_ID', ylabel='Item_Store_Returns'>

# %%
allnum = exc[["Item_Type","Item_Price","Item_Store_Returns"]]
allnumsum = allnum.groupby("Item_Type").sum()
allnumsum.sort_values("Item_Store_Returns", ascending=False )
# Out:
#                        Item_Price  Item_Store_Returns
# Item_Type
# Fruits and Vegetables   297491.34          4753680.69
# Snack Foods             299676.96          4744323.12
# Household               226799.67          3488712.43
# Frozen Foods            177348.49          2750915.93
# Canned                  147285.83          2334080.29
# Dairy                   143326.52          2173104.79
# Baking Goods            125532.11          1944151.22
# Health and Hygiene      112712.91          1657208.00
# Meat                    103211.54          1606164.39
# Soft Drinks             101006.54          1573069.09
# Breads                   54685.91           835605.63
# Hard Drinks              50464.24           805083.80
# Starchy Foods            34125.25           567892.48
# Others                   38860.77           556334.25
# Breakfast                26092.99           403681.24
# Seafood                  16479.87           262558.27

# %%
exc["Item_Type"].unique()
# Out:
# array(['Soft Drinks', 'Dairy', 'Hard Drinks', 'Canned', 'Frozen Foods',
#        'Fruits and Vegetables', 'Snack Foods', 'Baking Goods',
#        'Starchy Foods', 'Meat', 'Seafood', 'Breakfast', 'Breads',
#        'Health and Hygiene', 'Household', 'Others'], dtype=object)

# %%
# cl2new = exc[exc["Store_Location_Type"] == "Cluster 2"][["Item_Type","Item_Store_Returns"]]
cl2itemgrp = cl2new.groupby("Item_Type").sum()
cl2itemgrp.sort_values("Item_Store_Returns", ascending=False )
#
# Out:
#                        Item_Store_Returns
# Item_Type
# Snack Foods                    1834971.57
# Fruits and Vegetables          1829210.72
# Household                      1405242.59
# Frozen Foods                   1158172.43
# Canned                          964681.02
# Dairy                           948227.42
# Baking Goods                    694063.28
# Soft Drinks                     630773.97
# Health and Hygiene              595205.30
# Meat                            547876.84
# Hard Drinks                     318413.88
# Breads                          315935.42
# Starchy Foods                   262311.92
# Others                          216275.18
# Breakfast                       158753.36
# Seafood                         116227.05

# %%
cl3new = exc[exc["Store_Location_Type"] == "Cluster 3"][["Item_Type","Item_Store_Returns"]]
cl3itemgrp = cl3new.groupby("Item_Type").sum()
cl3itemgrp.sort_values("Item_Store_Returns", ascending=False )
#
# Out:
#                        Item_Store_Returns
# Item_Type
# Fruits and Vegetables          1795727.60
# Snack Foods                    1771960.27
# Household                      1272705.07
# Frozen Foods                    984581.82
# Canned                          818682.76
# Dairy                           783127.34
# Baking Goods                    728934.58
# Meat                            675146.21
# Health and Hygiene              592850.01
# Soft Drinks                     578363.85
# Breads                          340733.14
# Hard Drinks                     302586.20
# Others                          171265.41
# Starchy Foods                   162017.45
# Breakfast                       158761.71
# Seafood                          84604.88

# %%
# cl23merge = cl2itemsort
# sns.heatmap()
exc.head(2)
# Out:
#   Item_ID      Store_ID       Item_Store_ID  Item_Weight Item_Sugar_Content  \
# 0   DRA12  BABATUNJI010  DRA12_BABATUNJI010         11.6          Low Sugar
# 1   DRA12  BABATUNJI013  DRA12_BABATUNJI013         11.6          Low Sugar
#
#    Item_Visibility    Item_Type  Item_Price  Store_Start_Year Store_Size  \
# 0         0.068535  Soft Drinks      357.54              2005        NaN
# 1         0.040912  Soft Drinks      355.79              1994       High
#
#   Store_Location_Type         Store_Type  Item_Store_Returns
# 0           Cluster 3      Grocery Store              709.08
# 1           Cluster 3  Supermarket Type1             6381.69

# %%
cluster2 = exc[exc["Store_Location_Type"] == "Cluster 2"][["Item_Type","Store_Size","Item_Store_Returns", "Store_Type"]]

# %%
# cluster2grp = cluster2.groupby("Item_Type").sum()
# cluster2grp.sort_values("Item_Store_Returns", ascending=False)
